# %%
import time
import os

import requests
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.action_chains import ActionChains

# %%
def getReviews(reviews, dict_):
    for review in reviews:
        review_head = review.find("a", class_="fCitC").get_text()
        review = review.find("q", class_="XllAv H4 _a").get_text()
        dict_[review_head] = review

# %%
def getNegativeReviews(hotel_url):
    negativeReviews = {}
    
    driver = webdriver.Firefox()
    driver.get(hotel_url)
    
    driver.find_element_by_xpath(f".//label[contains(text(),'Poor')]").click()
    driver.find_element_by_xpath(f".//label[contains(text(),'Terrible')]").click()

    time.sleep(3)

    page_source = driver.page_source
    soup = BeautifulSoup(page_source, 'html.parser')
    reviews = soup.find_all("div", class_="cWwQK MC R2 Gi z Z BB dXjiy")
    
    while True:        
        getReviews(reviews, negativeReviews)        
        
        pagination = soup.find("div", class_="ui_pagination is-centered")
        next_button = pagination.find("a", class_="ui_button nav next primary")
        
        if next_button:
            if "disabled" not in next_button['class']:
                driver.find_element_by_link_text("Next").click()                    
                time.sleep(3)       
                page_source = driver.page_source
                soup = BeautifulSoup(page_source, 'html.parser')
                reviews = soup.find_all("div", class_="cWwQK MC R2 Gi z Z BB dXjiy")
                continue
            else:
                break

        break
    
    driver.close()
    return negativeReviews

# %%
hotel_url = 'https://www.tripadvisor.com/Hotel_Review-g293890-d648412-Reviews-Hotel_Blue_Horizon-Kathmandu_Kathmandu_Valley_Bagmati_Zone_Central_Region.html'
negative = getNegativeReviews(hotel_url)

# %%
negativeDataframe = pd.DataFrame({'heading': negative.keys(),
                                  'reviews': negative.values()})

# %%
negativeDataframe
# Out:
#                                               heading  \
# 0   Worst KTM "hotel" in 10 years of travelling th...
# 1   Promised airport pick up was an hour late, no ...
# 2                  Bad Experience with Trekkers' Home
# 3                                           No return
# 4         Cramped dark room, broken bathroom fittings
# 5             Stayed one night and left straight away
# 6                            I was not offered a room
# 7                                              Title
# 8                         Most terrible stay in Nepal
# 9                             Cheap and good location
# 10                     Cheap room, uncomfortable beds
# 11           They did not respect our confirmed order
# 12                 “Not bad, but room needs updating”
# 13       Much too expensive for a minor Budget hotel
# 14                                  Don't Stay Here!!
# 15                                         Overpriced
# 16                                  Real budget stay!
# 17                Not a good choice during the winter
# 18                    Moldy. Noisy. Dirty. Expensive.
# 19           Friendly staff but poor value for money.
# 20                                  Not a good choice
# 21                                   Awful experience
# 22                                Totally worst hotel
# 23                                Terrible All Around
# 24                       Damp, unhelpful, impractical
# 25                                            Rubbish
# 26                           Pay too much for nothing
# 27                                    Airport pick up
# 28                      Grunge in the heart of Thamel
# 29                             Everyday something new
# 30                                       Not worth it
# 31                                           Dreadful
# 32                                It was a nightmare!
# 33             Terrible totally terrible and all lies
#
#                                               reviews
# 0   Did not get the family room that was booked 3 ...
# 1   “Will the driver be waiting at the airport wit...
# 2   I booked a triple room with AC with Trekkers' ...
# 3   Very old room, poor lighting, dirty mattess an...
# 4   We arrived here after completing our trek and ...
# 5   The room we were given was damp and not very c...
# 6   The hotel person doesn’t provided me with the ...
# 7   You always get what you pay for. Trekkers Home...
# 8   Me and my boyfriend only stayed for one night ...
# 9   That’s very good located in Thamel, touristic ...
# 10  Really not too many good things to say about t...
# 11  We arrived to the hotel afternoon with a lot o...
# 12  We spend two night in this hotel. Hotel is old...
# 13  We are a family of five with small kids. We lo...
# 14  I do not understand why this hotel has so many...
# 15  For the money you can find much better places ...
# 16  Guess they've arranged a low class room for me...
# 17  I am staying in this hotel now and will be cha...
# 18  I hate to leave a bad review but I also want t...
# 19  Stayed here for one night before our trek. Goo...
# 20  I made a reservation for 4 days but left after...
# 21  Me and my friend had booked to stay here for 3...
# 22  We have booked for three night at this hotel a...
# 23  Terrible place.  They didn't send a pick up as...
# 24  So I stayed here for 3 nights mid October, I b...
# 25  Maybe you stay in the less expensive rooms but...
# 26  We pay deluxe room for 3 nights...the bathroom...
# 27  The airport pick up is not free and the staff ...
# 28  I really can't understand the 4 and 5 ratings ...
# 29  I would love to say something good about this ...
# 30  Staff is nice, no doubt about that... But: we ...
# 31  We had arranged the booking for 5 days over th...
# 32  We booked the hotel through Agoda for 2 nights...
# 33  This place is not as it looks, when u r at the...

# %%
def concatExcel():
    negativeExcel = pd.read_excel('negative.xlsx', header=0, index_col=0)
    negativeConcat = pd.concat([negativeExcel, negativeDataframe])
    negativeConcat.to_excel('negative.xlsx')

# %%
concatExcel()
